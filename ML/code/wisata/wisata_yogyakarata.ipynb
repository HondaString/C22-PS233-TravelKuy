# %%
import numpy as np
import pandas as pd 

# Untuk visualisasi data
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
sns.set_palette('Set1')
sns.set()

# Untuk pemodelan
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Untuk menghilangkan warnings saat plotting seaborn
import warnings
warnings.filterwarnings('ignore')

# %%
# package = pd.read_csv('../../data/wisata/package_tourism.csv')
rating = pd.read_csv('tourism_rating.csv')
place = pd.read_csv('tourism_with_id.csv')
user = pd.read_csv('user.csv')

# %%
# Melihat gambaran data place

place.head()
# Out:
#    Place_Id                         Place_Name  \
# 0         1                   Monumen Nasional
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City  \
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#    Rating  Time_Minutes                                       Coordinate  \
# 0     4.6          15.0          {'lat': -6.1753924, 'lng': 106.8271528}
# 1     4.6          90.0  {'lat': -6.137644799999999, 'lng': 106.8171245}
# 2     4.6         360.0  {'lat': -6.125312399999999, 'lng': 106.8335377}
# 3     4.5           NaN  {'lat': -6.302445899999999, 'lng': 106.8951559}
# 4     4.5          60.0             {'lat': -6.12419, 'lng': 106.839134}
#
#         Lat        Long   Price  Unnamed: 11
# 0 -6.175392  106.827153   20000            1
# 1 -6.137645  106.817125       0            2
# 2 -6.125312  106.833538  270000            3
# 3 -6.302446  106.895156   10000            4
# 4 -6.124190  106.839134   94000            5

# %%
# Merubah data agar hanya dari Kota Yogyakarta

place = place[place['City']=='Yogyakarta']
place.head()
# Out:
#     Place_Id                           Place_Name  \
# 84        85              Taman Pintar Yogyakarta
# 85        86                   Keraton Yogyakarta
# 86        87           Sindu Kusuma Edupark (SKE)
# 87        88  Museum Benteng Vredeburg Yogyakarta
# 88        89                 De Mata Museum Jogja
#
#                                           Description       Category  \
# 84  Taman Pintar Yogyakarta (bahasa Jawa: Hanacara...  Taman Hiburan
# 85  Keraton Ngayogyakarta Hadiningrat atau Keraton...         Budaya
# 86  Sindu Kusuma Edupark (SKE) merupakan sebuah de...  Taman Hiburan
# 87  Museum Benteng Vredeburg (bahasa Jawa: ꦩꦸꦱꦶꦪꦸꦩ...         Budaya
# 88  Museum De Mata merupakan salah satu museum yan...         Budaya
#
#           City  Rating  Time_Minutes  \
# 84  Yogyakarta     4.5         120.0
# 85  Yogyakarta     4.6           NaN
# 86  Yogyakarta     4.2         120.0
# 87  Yogyakarta     4.6         120.0
# 88  Yogyakarta     4.4           NaN
#
#                                          Coordinate       Lat        Long  \
# 84  {'lat': -7.800671500000001, 'lng': 110.3676551} -7.800671  110.367655
# 85          {'lat': -7.8052845, 'lng': 110.3642031} -7.805284  110.364203
# 86  {'lat': -7.767297300000001, 'lng': 110.3542486} -7.767297  110.354249
# 87  {'lat': -7.800201599999999, 'lng': 110.3663044} -7.800202  110.366304
# 88  {'lat': -7.816315599999999, 'lng': 110.3871442} -7.816316  110.387144
#
#     Price  Unnamed: 11
# 84   6000           85
# 85  15000           86
# 86  20000           87
# 87   3000           88
# 88  50000           89

# %%
# melihat gambaran data rating

rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        1       179              3
# 1        1       344              2
# 2        1         5              5
# 3        1       373              3
# 4        1       101              4

# %%
# Merubah data rating agar hanya berisi rating pada tempat wisata dari Kota Yogyakarta

rating = pd.merge(rating, place[['Place_Id']], how='right', on='Place_Id')
rating.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        2        85              4
# 1       23        85              4
# 2       25        85              2
# 3       39        85              5
# 4       43        85              4

# %%
# Melihat ukuran dataset rating untuk Kota Yogyakarta

rating.shape
# Out:
# (2871, 3)

# %%
# Melihat gambaran data user

user.head()
# Out:
#    User_Id                   Location  Age
# 0        1      Semarang, Jawa Tengah   20
# 1        2         Bekasi, Jawa Barat   21
# 2        3        Cirebon, Jawa Barat   23
# 3        4         Bekasi, Jawa Barat   21
# 4        5  Lampung, Sumatera Selatan   20

# %%
# Merubah data user agar hanya berisi user yang pernah megunjungi wisata di Kota Yogyakarta

user = pd.merge(user, rating[['User_Id']], how='right', on='User_Id').drop_duplicates().sort_values('User_Id')
user.head()
# Out:
#      User_Id                   Location  Age
# 101        1      Semarang, Jawa Tengah   20
# 0          2         Bekasi, Jawa Barat   21
# 25         3        Cirebon, Jawa Barat   23
# 69         4         Bekasi, Jawa Barat   21
# 717        5  Lampung, Sumatera Selatan   20

# %%
# Melihat dataset user yang pernah memberi rating pada wisata di Kota Yogyakarta

user.shape
# Out:
# (300, 3)

# %%
# Membuat dataframe berisi lokasi dengan jumlah rating terbanyak
top_10 = rating['Place_Id'].value_counts().reset_index()[0:10]
top_10 = pd.merge(top_10, place[['Place_Id','Place_Name']], how='left', left_on='index', right_on='Place_Id')

# Membuat visualisasi wisata dengan jumlah rating terbanyak
plt.figure(figsize=(8,5))
sns.barplot('Place_Id_x', 'Place_Name', data=top_10)
plt.title('Jumlah Tempat Wisata dengan Rating Terbanyak', pad=20)
plt.ylabel('Jumlah Rating')
plt.xlabel('Nama Lokasi')
plt.show()

# %%
# Membuat visualisasi jumlah kategori wisata di Kota Yogyakarta

sns.countplot(y='Category', data=place)
plt.title('Perbandingan Jumlah Kategori Wisata di Kota Yogyakarta', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi usia user

plt.figure(figsize=(5,3))
sns.boxplot(user['Age']);
plt.title('Distribusi Usia User', pad=20)
plt.show()

# %%
# Membuat visualisasi distribusi harga masuk tempat wisata

plt.figure(figsize=(7,3))
sns.boxplot(place['Price'])
plt.title('Distribusi Harga Masuk Wisata di Kota Yogyakarta', pad=20)
plt.show()

# %%
# Memfilter asal kota dari user
askot = user['Location'].apply(lambda x : x.split(',')[0])

# Visualisasi asal kota dari user
plt.figure(figsize=(8,6))
sns.countplot(y=askot)
plt.title('Jumlah Asal Kota dari User')
plt.show()

# %% [markdown]
#  # MODELING

# %%
# Membaca dataset untuk dilakukan encoding
 
df = rating.copy()
df.head()
# Out:
#    User_Id  Place_Id  Place_Ratings
# 0        2        85              4
# 1       23        85              4
# 2       25        85              2
# 3       39        85              5
# 4       43        85              4

# %%
#ENCODING
def dict_encoder(col, data=df):

  # Mengubah kolom suatu dataframe menjadi list tanpa nilai yang sama
  unique_val = data[col].unique().tolist()

  # Melakukan encoding value kolom suatu dataframe ke angka
  val_to_val_encoded = {x: i for i, x in enumerate(unique_val)}

  # Melakukan proses encoding angka ke value dari kolom suatu dataframe
  val_encoded_to_val = {i: x for i, x in enumerate(unique_val)}
  return val_to_val_encoded, val_encoded_to_val

# %%
# ENCODING + MAPING 

# Encoding User_Id
user_to_user_encoded, user_encoded_to_user = dict_encoder('User_Id')

# Mapping User_Id ke dataframe
df['user'] = df['User_Id'].map(user_to_user_encoded)

# %%
# Encoding Place_Id
place_to_place_encoded, place_encoded_to_place = dict_encoder('Place_Id')

# Mapping Place_Id ke dataframe place
df['place'] = df['Place_Id'].map(place_to_place_encoded)

# %%
# Mendapatkan jumlah user dan place
num_users, num_place = len(user_to_user_encoded), len(place_to_place_encoded)
 
# Mengubah rating menjadi nilai float
df['Place_Ratings'] = df['Place_Ratings'].values.astype(np.float32)
 
# Mendapatkan nilai minimum dan maksimum rating
min_rating, max_rating = min(df['Place_Ratings']), max(df['Place_Ratings'])
 
print(f'Number of User: {num_users}, Number of Place: {num_place}, Min Rating: {min_rating}, Max Rating: {max_rating}')
# Out:
# Number of User: 300, Number of Place: 126, Min Rating: 1.0, Max Rating: 5.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42)
df.head(2)
# Out:
#       User_Id  Place_Id  Place_Ratings  user  place
# 729       194       115            4.0   130     30
# 2067      276       176            2.0    23     91

# %%
# Membuat variabel x untuk mencocokkan data user dan place menjadi satu value
x = df[['user', 'place']].values
 
# Membuat variabel y untuk membuat rating dari hasil 
y = df['Place_Ratings'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
 
# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)

# %%
class RecommenderNet(tf.keras.Model):
 
  # Insialisasi fungsi
  def __init__(self, num_users, num_places, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_places = num_places
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding( # layer embedding user
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1) # layer embedding user bias
    self.places_embedding = layers.Embedding( # layer embeddings places
        num_places,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.places_bias = layers.Embedding(num_places, 1) # layer embedding places bias
 
  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0]) # memanggil layer embedding 1
    user_bias = self.user_bias(inputs[:, 0]) # memanggil layer embedding 2
    places_vector = self.places_embedding(inputs[:, 1]) # memanggil layer embedding 3
    places_bias = self.places_bias(inputs[:, 1]) # memanggil layer embedding 4
 
    dot_user_places = tf.tensordot(user_vector, places_vector, 2) 
 
    x = dot_user_places + user_bias + places_bias
    
    return tf.nn.sigmoid(x) # activation sigmoid

# %%
model = RecommenderNet(num_users, num_place, 50) # inisialisasi model
 
# model compile
model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.0004),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %%
 class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('val_root_mean_squared_error')<0.25):
      print('Lapor! Metriks validasi sudah sesuai harapan')
      self.model.stop_training = True

# %%
# Memulai training
 
history = model.fit(
    x = x_train,
    y = y_train,
    epochs = 100,
    validation_data = (x_val, y_val),
    callbacks = [myCallback()]
)
# Out:
# Epoch 1/100
# 72/72 [==============================] - 2s 7ms/step - loss: 0.7117 - root_mean_squared_error: 0.3632 - val_loss: 0.7213 - val_root_mean_squared_error: 0.3601
# Epoch 2/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7182 - root_mean_squared_error: 0.3673 - val_loss: 0.7213 - val_root_mean_squared_error: 0.3600
# Epoch 3/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7096 - root_mean_squared_error: 0.3623 - val_loss: 0.7204 - val_root_mean_squared_error: 0.3594
# Epoch 4/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7076 - root_mean_squared_error: 0.3609 - val_loss: 0.7207 - val_root_mean_squared_error: 0.3596
# Epoch 5/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7083 - root_mean_squared_error: 0.3615 - val_loss: 0.7199 - val_root_mean_squared_error: 0.3590
# Epoch 6/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.7067 - root_mean_squared_error: 0.3601 - val_loss: 0.7188 - val_root_mean_squared_error: 0.3583
# Epoch 7/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7025 - root_mean_squared_error: 0.3573 - val_loss: 0.7184 - val_root_mean_squared_error: 0.3581
# Epoch 8/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7035 - root_mean_squared_error: 0.3580 - val_loss: 0.7182 - val_root_mean_squared_error: 0.3579
# Epoch 9/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7034 - root_mean_squared_error: 0.3579 - val_loss: 0.7181 - val_root_mean_squared_error: 0.3579
# Epoch 10/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.7034 - root_mean_squared_error: 0.3580 - val_loss: 0.7178 - val_root_mean_squared_error: 0.3576
# Epoch 11/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6961 - root_mean_squared_error: 0.3531 - val_loss: 0.7180 - val_root_mean_squared_error: 0.3578
# Epoch 12/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6965 - root_mean_squared_error: 0.3534 - val_loss: 0.7166 - val_root_mean_squared_error: 0.3569
# Epoch 13/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6988 - root_mean_squared_error: 0.3549 - val_loss: 0.7168 - val_root_mean_squared_error: 0.3570
# Epoch 14/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6944 - root_mean_squared_error: 0.3521 - val_loss: 0.7156 - val_root_mean_squared_error: 0.3562
# Epoch 15/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6941 - root_mean_squared_error: 0.3519 - val_loss: 0.7159 - val_root_mean_squared_error: 0.3563
# Epoch 16/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6979 - root_mean_squared_error: 0.3544 - val_loss: 0.7150 - val_root_mean_squared_error: 0.3559
# Epoch 17/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6991 - root_mean_squared_error: 0.3549 - val_loss: 0.7151 - val_root_mean_squared_error: 0.3558
# Epoch 18/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6926 - root_mean_squared_error: 0.3507 - val_loss: 0.7140 - val_root_mean_squared_error: 0.3552
# Epoch 19/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6882 - root_mean_squared_error: 0.3477 - val_loss: 0.7140 - val_root_mean_squared_error: 0.3552
# Epoch 20/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6875 - root_mean_squared_error: 0.3472 - val_loss: 0.7138 - val_root_mean_squared_error: 0.3551
# Epoch 21/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6886 - root_mean_squared_error: 0.3480 - val_loss: 0.7140 - val_root_mean_squared_error: 0.3552
# Epoch 22/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6898 - root_mean_squared_error: 0.3489 - val_loss: 0.7142 - val_root_mean_squared_error: 0.3553
# Epoch 23/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6852 - root_mean_squared_error: 0.3456 - val_loss: 0.7154 - val_root_mean_squared_error: 0.3561
# Epoch 24/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6865 - root_mean_squared_error: 0.3466 - val_loss: 0.7156 - val_root_mean_squared_error: 0.3562
# Epoch 25/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6851 - root_mean_squared_error: 0.3455 - val_loss: 0.7151 - val_root_mean_squared_error: 0.3559
# Epoch 26/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6858 - root_mean_squared_error: 0.3461 - val_loss: 0.7148 - val_root_mean_squared_error: 0.3557
# Epoch 27/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6829 - root_mean_squared_error: 0.3439 - val_loss: 0.7140 - val_root_mean_squared_error: 0.3552
# Epoch 28/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6844 - root_mean_squared_error: 0.3451 - val_loss: 0.7136 - val_root_mean_squared_error: 0.3550
# Epoch 29/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6832 - root_mean_squared_error: 0.3442 - val_loss: 0.7131 - val_root_mean_squared_error: 0.3546
# Epoch 30/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6774 - root_mean_squared_error: 0.3401 - val_loss: 0.7139 - val_root_mean_squared_error: 0.3551
# Epoch 31/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6767 - root_mean_squared_error: 0.3396 - val_loss: 0.7143 - val_root_mean_squared_error: 0.3554
# Epoch 32/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6786 - root_mean_squared_error: 0.3409 - val_loss: 0.7145 - val_root_mean_squared_error: 0.3555
# Epoch 33/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6764 - root_mean_squared_error: 0.3393 - val_loss: 0.7148 - val_root_mean_squared_error: 0.3557
# Epoch 34/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6778 - root_mean_squared_error: 0.3404 - val_loss: 0.7156 - val_root_mean_squared_error: 0.3563
# Epoch 35/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6754 - root_mean_squared_error: 0.3386 - val_loss: 0.7163 - val_root_mean_squared_error: 0.3567
# Epoch 36/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6744 - root_mean_squared_error: 0.3379 - val_loss: 0.7156 - val_root_mean_squared_error: 0.3563
# Epoch 37/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6740 - root_mean_squared_error: 0.3375 - val_loss: 0.7164 - val_root_mean_squared_error: 0.3568
# Epoch 38/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6753 - root_mean_squared_error: 0.3385 - val_loss: 0.7158 - val_root_mean_squared_error: 0.3564
# Epoch 39/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6732 - root_mean_squared_error: 0.3370 - val_loss: 0.7155 - val_root_mean_squared_error: 0.3562
# Epoch 40/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6721 - root_mean_squared_error: 0.3363 - val_loss: 0.7151 - val_root_mean_squared_error: 0.3559
# Epoch 41/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6736 - root_mean_squared_error: 0.3373 - val_loss: 0.7157 - val_root_mean_squared_error: 0.3563
# Epoch 42/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6709 - root_mean_squared_error: 0.3354 - val_loss: 0.7159 - val_root_mean_squared_error: 0.3565
# Epoch 43/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6710 - root_mean_squared_error: 0.3354 - val_loss: 0.7156 - val_root_mean_squared_error: 0.3563
# Epoch 44/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6686 - root_mean_squared_error: 0.3337 - val_loss: 0.7155 - val_root_mean_squared_error: 0.3562
# Epoch 45/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6724 - root_mean_squared_error: 0.3364 - val_loss: 0.7156 - val_root_mean_squared_error: 0.3563
# Epoch 46/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6719 - root_mean_squared_error: 0.3361 - val_loss: 0.7157 - val_root_mean_squared_error: 0.3563
# Epoch 47/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6694 - root_mean_squared_error: 0.3343 - val_loss: 0.7158 - val_root_mean_squared_error: 0.3564
# Epoch 48/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6687 - root_mean_squared_error: 0.3337 - val_loss: 0.7154 - val_root_mean_squared_error: 0.3562
# Epoch 49/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6696 - root_mean_squared_error: 0.3345 - val_loss: 0.7150 - val_root_mean_squared_error: 0.3559
# Epoch 50/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6663 - root_mean_squared_error: 0.3320 - val_loss: 0.7152 - val_root_mean_squared_error: 0.3560
# Epoch 51/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6690 - root_mean_squared_error: 0.3340 - val_loss: 0.7154 - val_root_mean_squared_error: 0.3561
# Epoch 52/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6648 - root_mean_squared_error: 0.3310 - val_loss: 0.7149 - val_root_mean_squared_error: 0.3558
# Epoch 53/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6678 - root_mean_squared_error: 0.3331 - val_loss: 0.7145 - val_root_mean_squared_error: 0.3555
# Epoch 54/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6659 - root_mean_squared_error: 0.3317 - val_loss: 0.7144 - val_root_mean_squared_error: 0.3555
# Epoch 55/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6631 - root_mean_squared_error: 0.3297 - val_loss: 0.7150 - val_root_mean_squared_error: 0.3558
# Epoch 56/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6643 - root_mean_squared_error: 0.3307 - val_loss: 0.7146 - val_root_mean_squared_error: 0.3555
# Epoch 57/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6660 - root_mean_squared_error: 0.3318 - val_loss: 0.7152 - val_root_mean_squared_error: 0.3559
# Epoch 58/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6644 - root_mean_squared_error: 0.3306 - val_loss: 0.7156 - val_root_mean_squared_error: 0.3562
# Epoch 59/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6613 - root_mean_squared_error: 0.3283 - val_loss: 0.7164 - val_root_mean_squared_error: 0.3568
# Epoch 60/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6649 - root_mean_squared_error: 0.3309 - val_loss: 0.7167 - val_root_mean_squared_error: 0.3570
# Epoch 61/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6631 - root_mean_squared_error: 0.3297 - val_loss: 0.7168 - val_root_mean_squared_error: 0.3570
# Epoch 62/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6636 - root_mean_squared_error: 0.3301 - val_loss: 0.7168 - val_root_mean_squared_error: 0.3570
# Epoch 63/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6631 - root_mean_squared_error: 0.3297 - val_loss: 0.7166 - val_root_mean_squared_error: 0.3569
# Epoch 64/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6618 - root_mean_squared_error: 0.3288 - val_loss: 0.7163 - val_root_mean_squared_error: 0.3567
# Epoch 65/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6623 - root_mean_squared_error: 0.3290 - val_loss: 0.7160 - val_root_mean_squared_error: 0.3565
# Epoch 66/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6622 - root_mean_squared_error: 0.3291 - val_loss: 0.7162 - val_root_mean_squared_error: 0.3567
# Epoch 67/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6610 - root_mean_squared_error: 0.3282 - val_loss: 0.7168 - val_root_mean_squared_error: 0.3570
# Epoch 68/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6602 - root_mean_squared_error: 0.3276 - val_loss: 0.7167 - val_root_mean_squared_error: 0.3569
# Epoch 69/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6611 - root_mean_squared_error: 0.3282 - val_loss: 0.7161 - val_root_mean_squared_error: 0.3566
# Epoch 70/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6598 - root_mean_squared_error: 0.3273 - val_loss: 0.7163 - val_root_mean_squared_error: 0.3567
# Epoch 71/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6613 - root_mean_squared_error: 0.3284 - val_loss: 0.7165 - val_root_mean_squared_error: 0.3568
# Epoch 72/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6589 - root_mean_squared_error: 0.3266 - val_loss: 0.7178 - val_root_mean_squared_error: 0.3577
# Epoch 73/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6610 - root_mean_squared_error: 0.3282 - val_loss: 0.7177 - val_root_mean_squared_error: 0.3576
# Epoch 74/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6592 - root_mean_squared_error: 0.3268 - val_loss: 0.7171 - val_root_mean_squared_error: 0.3572
# Epoch 75/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6586 - root_mean_squared_error: 0.3265 - val_loss: 0.7176 - val_root_mean_squared_error: 0.3574
# Epoch 76/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6605 - root_mean_squared_error: 0.3278 - val_loss: 0.7175 - val_root_mean_squared_error: 0.3574
# Epoch 77/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6577 - root_mean_squared_error: 0.3257 - val_loss: 0.7163 - val_root_mean_squared_error: 0.3567
# Epoch 78/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6580 - root_mean_squared_error: 0.3260 - val_loss: 0.7160 - val_root_mean_squared_error: 0.3565
# Epoch 79/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6594 - root_mean_squared_error: 0.3271 - val_loss: 0.7160 - val_root_mean_squared_error: 0.3565
# Epoch 80/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6575 - root_mean_squared_error: 0.3255 - val_loss: 0.7162 - val_root_mean_squared_error: 0.3566
# Epoch 81/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6576 - root_mean_squared_error: 0.3256 - val_loss: 0.7167 - val_root_mean_squared_error: 0.3569
# Epoch 82/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6541 - root_mean_squared_error: 0.3231 - val_loss: 0.7169 - val_root_mean_squared_error: 0.3571
# Epoch 83/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6567 - root_mean_squared_error: 0.3252 - val_loss: 0.7173 - val_root_mean_squared_error: 0.3574
# Epoch 84/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6578 - root_mean_squared_error: 0.3257 - val_loss: 0.7177 - val_root_mean_squared_error: 0.3576
# Epoch 85/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6584 - root_mean_squared_error: 0.3262 - val_loss: 0.7180 - val_root_mean_squared_error: 0.3578
# Epoch 86/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6577 - root_mean_squared_error: 0.3257 - val_loss: 0.7175 - val_root_mean_squared_error: 0.3575
# Epoch 87/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6553 - root_mean_squared_error: 0.3240 - val_loss: 0.7170 - val_root_mean_squared_error: 0.3572
# Epoch 88/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6572 - root_mean_squared_error: 0.3254 - val_loss: 0.7171 - val_root_mean_squared_error: 0.3572
# Epoch 89/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6551 - root_mean_squared_error: 0.3238 - val_loss: 0.7172 - val_root_mean_squared_error: 0.3573
# Epoch 90/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6547 - root_mean_squared_error: 0.3235 - val_loss: 0.7177 - val_root_mean_squared_error: 0.3576
# Epoch 91/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6558 - root_mean_squared_error: 0.3243 - val_loss: 0.7176 - val_root_mean_squared_error: 0.3575
# Epoch 92/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6545 - root_mean_squared_error: 0.3234 - val_loss: 0.7171 - val_root_mean_squared_error: 0.3573
# Epoch 93/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6546 - root_mean_squared_error: 0.3235 - val_loss: 0.7165 - val_root_mean_squared_error: 0.3569
# Epoch 94/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6544 - root_mean_squared_error: 0.3232 - val_loss: 0.7162 - val_root_mean_squared_error: 0.3567
# Epoch 95/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6542 - root_mean_squared_error: 0.3231 - val_loss: 0.7165 - val_root_mean_squared_error: 0.3569
# Epoch 96/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6548 - root_mean_squared_error: 0.3237 - val_loss: 0.7170 - val_root_mean_squared_error: 0.3572
# Epoch 97/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6531 - root_mean_squared_error: 0.3224 - val_loss: 0.7171 - val_root_mean_squared_error: 0.3573
# Epoch 98/100
# 72/72 [==============================] - 0s 3ms/step - loss: 0.6538 - root_mean_squared_error: 0.3228 - val_loss: 0.7179 - val_root_mean_squared_error: 0.3577
# Epoch 99/100
# 72/72 [==============================] - 0s 4ms/step - loss: 0.6536 - root_mean_squared_error: 0.3228 - val_loss: 0.7182 - val_root_mean_squared_error: 0.3579
# Epoch 100/100
# 72/72 [==============================] - 1s 8ms/step - loss: 0.6546 - root_mean_squared_error: 0.3235 - val_loss: 0.7175 - val_root_mean_squared_error: 0.3575

# %%
# Menampilkan plot loss dan validation

plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.ylim(ymin=0, ymax=0.4)
plt.legend(['train', 'test'], loc='center left')
plt.show()

# %% [markdown]
# # MEMBUAT TOP 5 REKOMENDASI

# %%
place.columns
# Out:
# Index(['Place_Id', 'Place_Name', 'Description', 'Category', 'City', 'Rating',
#        'Time_Minutes', 'Coordinate', 'Lat', 'Long', 'Price', 'Unnamed: 11'],
#       dtype='object')

# %%
# Menyiapkan dataframe
place_df = place[['Place_Id', 'Place_Name', 'Description', 'Category', 'City', 'Rating',
       'Time_Minutes', 'Coordinate', 'Lat', 'Long', 'Price']]
place_df.columns = ['Place_Id', 'Place_Name', 'Description', 'Category', 'City', 'Rating',
       'Time_Minutes', 'Coordinate', 'Lat', 'Long', 'Price']
df = rating.copy()

# %%
# Mengambil sample user
user_id = df.User_Id.sample(1).iloc[0]
place_visited_by_user = df[df.User_Id == user_id]

# %%
# Membuat data lokasi yang belum dikunjungi user
place_not_visited = place_df[~place_df['Place_Id'].isin(place_visited_by_user.Place_Id.values)]['Place_Id'] 
place_not_visited = list(
    set(place_not_visited)
    .intersection(set(place_to_place_encoded.keys()))
)
 
place_not_visited = [[place_to_place_encoded.get(x)] for x in place_not_visited]
user_encoder = user_to_user_encoded.get(user_id)
user_place_array = np.hstack(
    ([[user_encoder]] * len(place_not_visited), place_not_visited)
)

# %%
# Mengambil top 5 recommendation
ratings = model.predict(user_place_array).flatten()
top_ratings_indices = ratings.argsort()[-5:][::-1]
recommended_place_ids = [
    place_encoded_to_place.get(place_not_visited[x][0]) for x in top_ratings_indices
]
 

print('')
print('----' * 15)
print('Top 5 place recommendation')
print('----' * 15)
 
recommended_place = place_df[place_df['Place_Id'].isin(recommended_place_ids)]
for row, i in zip(recommended_place.itertuples(), range(1,8)):
    print(i,'.', row.Place_Name, '\n    ', row.Category, ',', 'Harga Tiket Masuk ', row.Price, ',', 'Rating Wisata ',row.Rating,'\n')

print('==='*15)
# Out:
# ------------------------------------------------------------
# Top 5 place recommendation
# ------------------------------------------------------------
# 1 . Situs Warungboto
#      Taman Hiburan , Harga Tiket Masuk  0 , Rating Wisata  4.4
#
# 2 . Sumur Gumuling
#      Taman Hiburan , Harga Tiket Masuk  7000 , Rating Wisata  4.5
#
# 3 . Monumen Yogya Kembali
#      Budaya , Harga Tiket Masuk  15000 , Rating Wisata  4.5
#
# 4 . Bukit Bintang Yogyakarta
#      Taman Hiburan , Harga Tiket Masuk  25000 , Rating Wisata  4.5
#
# 5 . The World Landmarks - Merapi Park Yogyakarta
#      Taman Hiburan , Harga Tiket Masuk  22000 , Rating Wisata  4.2
#
# =============================================

# %% [markdown]
# ## Save Model

# %%
model.save_weights('./checkpoints/my_checkpoint')

# %% [markdown]
# ## Load Model

# %%
model_load = RecommenderNet(num_users, num_place, 50)
model_load.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.0004),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)
model_load.load_weights('./checkpoints/my_checkpoint')

# %%
model.evaluate(x=x_val, y=y_val)
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7175 - root_mean_squared_error: 0.3575
# [0.7174824476242065, 0.3574642241001129]

# %%
model_load.evaluate(x=x_val, y=y_val)
# Out:
# 18/18 [==============================] - 0s 2ms/step - loss: 0.7175 - root_mean_squared_error: 0.3575
# [0.7174824476242065, 0.3574642241001129]

# %%
# Mengambil top 5 recommendation
ratings = model_load.predict(user_place_array).flatten()
top_ratings_indices = ratings.argsort()[-5:][::-1]
recommended_place_ids = [
    place_encoded_to_place.get(place_not_visited[x][0]) for x in top_ratings_indices
]
 

print('')
print('----' * 15)
print('Top 5 place recommendation')
print('----' * 15)
 
recommended_place = place_df[place_df['Place_Id'].isin(recommended_place_ids)]
for row, i in zip(recommended_place.itertuples(), range(1,8)):
    print(i,'.', row.Place_Name, '\n    ', row.Category, ',', 'Harga Tiket Masuk ', row.Price, ',', 'Rating Wisata ',row.Rating,'\n')

print('==='*15)
# Out:
# ------------------------------------------------------------
# Top 5 place recommendation
# ------------------------------------------------------------
# 1 . Situs Warungboto
#      Taman Hiburan , Harga Tiket Masuk  0 , Rating Wisata  4.4
#
# 2 . Sumur Gumuling
#      Taman Hiburan , Harga Tiket Masuk  7000 , Rating Wisata  4.5
#
# 3 . Monumen Yogya Kembali
#      Budaya , Harga Tiket Masuk  15000 , Rating Wisata  4.5
#
# 4 . Bukit Bintang Yogyakarta
#      Taman Hiburan , Harga Tiket Masuk  25000 , Rating Wisata  4.5
#
# 5 . The World Landmarks - Merapi Park Yogyakarta
#      Taman Hiburan , Harga Tiket Masuk  22000 , Rating Wisata  4.2
#
# =============================================
